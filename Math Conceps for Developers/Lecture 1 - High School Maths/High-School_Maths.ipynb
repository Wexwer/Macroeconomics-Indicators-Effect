# %% [markdown]
# ### Linear equation

# %% [markdown]
# $$ ax + b = 0, a \ne 0$$
# $$ x = - \frac{b}{a} $$

# %%
def solve_linear_equation(a,b):
    """
    This funnction returnnn the solutionn of the equaion $ax + b = 0$

    Parameters:
    a: float - the first coefficiennt
    b: float - the second coefficient

    Retunr:
    x: float or [] - the solution (or empty list if there's not a single solution)
    """
    if a == 0:
        return []
    return -b / a

# %%
solve_linear_equation(3.3,2)
# Out:
# -0.6060606060606061

# %%
solve_linear_equation(0,0)
# Out:
# []

# %%
solve
