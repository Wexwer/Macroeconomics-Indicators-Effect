# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# ### Probability and Combinatorics

# %% [markdown]
# ## Live demos

# %%
resutls = np.random.randint(1,7,200)
plt.plot(resutls)
plt.grid(None)
plt.show()

# %% [markdown]
# We will do function of the function plt.plot which is above

# %%
[result == 1 for result in resutls]
# Out:
# [np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.True_,
#  np.False_,
#  np.True_,
#  np.True_,
#  np.False_,
#  np.False_,
#  np.False_,
#  np.True_,
#  np.False_,
# ...

# %%
count = {}
for result in resutls:
    if result in count:
        count[result] += 1
    else:
        count[result] = 1

# %%
count
# Out:
# {np.int32(5): 32,
#  np.int32(6): 33,
#  np.int32(2): 30,
#  np.int32(3): 37,
#  np.int32(1): 40,
#  np.int32(4): 28}

# %%
Counter(resutls)
# Out:
# Counter({np.int32(1): 40,
#          np.int32(3): 37,
#          np.int32(6): 33,
#          np.int32(5): 32,
#          np.int32(2): 30,
#          np.int32(4): 28})
